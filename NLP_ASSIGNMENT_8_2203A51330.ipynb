# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisathvik-Achanta/Natural-Language-Processing/blob/main/NLP_ASSIGNMENT_8_2203A51330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, MultiHeadAttention, LayerNormalization, Dense, Dropout
from tensorflow.keras import Sequential, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

text = """Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her."""
vocab_size = 1000
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts([text])
sequences = tokenizer.texts_to_sequences([text])[0]
input_sequences = []
for i in range(1, len(sequences)):
    input_sequences.append(sequences[:i+1])
max_sequence_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')
X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=vocab_size)
class TransformerModel(Model):
    def __init__(self, vocab_size, embed_dim, num_heads, ff_dim):
        super(TransformerModel, self).__init__()
        self.embedding = Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.attention = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = Sequential([Dense(ff_dim, activation="relu"), Dense(embed_dim)])
        self.layernorm1 = LayerNormalization()
        self.layernorm2 = LayerNormalization()
        self.dropout1 = Dropout(0.1)
        self.dropout2 = Dropout(0.1)
        self.final_layer = Dense(vocab_size, activation="softmax")

    def call(self, inputs):
        x = self.embedding(inputs)
        attn_output = self.attention(x, x)
        x = self.layernorm1(x + self.dropout1(attn_output))
        ffn_output = self.dense_proj(x)
        x = self.layernorm2(x + self.dropout2(ffn_output))
        return self.final_layer(x[:, -1])

embed_dim = 128
num_heads = 4
ff_dim = 512
transformer_model = TransformerModel(vocab_size, embed_dim, num_heads, ff_dim)
transformer_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
epochs_list = [20,60,70]
for epochs in epochs_list:
    print(f"\nTraining model with {epochs} epochs:")
    transformer_model.fit(X, y, epochs=epochs, verbose=1)
def generate_text(model, tokenizer, seed_text, max_length=70):
    for _ in range(max_length):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=-1).item()
        output_word = tokenizer.index_word.get(predicted_word_index, "")
        seed_text += " " + output_word
    return seed_text
seed_text = "Once upon a time"
print("\nText Generated:", generate_text(transformer_model, tokenizer, seed_text))
# Out:
# Training model with 20 epochs:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.0000e+00 - loss: 6.9910
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - accuracy: 0.1837 - loss: 5.9728
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - accuracy: 0.3085 - loss: 5.3130
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.3345 - loss: 4.8364
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4610 - loss: 4.3243
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6360 - loss: 3.8020
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7920 - loss: 3.3239
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8042 - loss: 2.8838
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8163 - loss: 2.5178
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8388 - loss: 2.1732
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7937 - loss: 1.8529
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7955 - loss: 1.6403
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8492 - loss: 1.3943
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8388 - loss: 1.1896
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8492 - loss: 1.0432
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.8284 - loss: 0.9427
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8509 - loss: 0.8482
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8509 - loss: 0.7669
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9169 - loss: 0.6680
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8960 - loss: 0.6347
#
# Training model with 60 epochs:
# Epoch 1/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9081 - loss: 0.5846
# Epoch 2/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.8856 - loss: 0.5499
# Epoch 3/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9203 - loss: 0.5138
# Epoch 4/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9203 - loss: 0.5242
# Epoch 5/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 0.8873 - loss: 0.4665
# Epoch 6/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - accuracy: 0.9081 - loss: 0.4350
# Epoch 7/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9186 - loss: 0.3741
# Epoch 8/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.9307 - loss: 0.3804
# Epoch 9/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9203 - loss: 0.3678
# Epoch 10/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.9203 - loss: 0.3556
# Epoch 11/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9203 - loss: 0.3290
# Epoch 12/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9203 - loss: 0.3237
# Epoch 13/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.9098 - loss: 0.3135
# Epoch 14/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9428 - loss: 0.2912
# Epoch 15/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9307 - loss: 0.2748
# Epoch 16/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.9532 - loss: 0.2745
# Epoch 17/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9203 - loss: 0.2643
# Epoch 18/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8856 - loss: 0.2516
# Epoch 19/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9203 - loss: 0.2456
# Epoch 20/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9636 - loss: 0.1947
# Epoch 21/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9428 - loss: 0.2134
# Epoch 22/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9515 - loss: 0.1827
# Epoch 23/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9428 - loss: 0.2134
# Epoch 24/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 0.9636 - loss: 0.1778
# Epoch 25/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.9203 - loss: 0.2071
# Epoch 26/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.9532 - loss: 0.1634
# Epoch 27/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step - accuracy: 0.9532 - loss: 0.1753
# Epoch 28/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9879 - loss: 0.1660
# Epoch 29/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - accuracy: 0.9653 - loss: 0.1574
# Epoch 30/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - accuracy: 0.9428 - loss: 0.1586
# Epoch 31/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9428 - loss: 0.1619
# Epoch 32/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9428 - loss: 0.1574
# Epoch 33/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9879 - loss: 0.1274
# Epoch 34/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9775 - loss: 0.1468
# Epoch 35/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9653 - loss: 0.1275
# Epoch 36/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9758 - loss: 0.1193
# Epoch 37/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.9879 - loss: 0.1180
# Epoch 38/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9775 - loss: 0.1185
# Epoch 39/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.9758 - loss: 0.1204
# Epoch 40/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9879 - loss: 0.1066
# Epoch 41/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9653 - loss: 0.1094
# Epoch 42/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9653 - loss: 0.1193
# Epoch 43/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9428 - loss: 0.1229
# Epoch 44/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9653 - loss: 0.1206
# Epoch 45/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9758 - loss: 0.1161
# Epoch 46/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9775 - loss: 0.1032
# Epoch 47/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9879 - loss: 0.0767
# Epoch 48/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9879 - loss: 0.0737
# Epoch 49/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - accuracy: 0.9532 - loss: 0.1088
# Epoch 50/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - accuracy: 0.9758 - loss: 0.1034
# Epoch 51/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - accuracy: 0.9775 - loss: 0.0966
# Epoch 52/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - accuracy: 0.9653 - loss: 0.1263
# Epoch 53/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.9775 - loss: 0.0946
# Epoch 54/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 0.9775 - loss: 0.0810
# Epoch 55/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9653 - loss: 0.0840
# Epoch 56/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9879 - loss: 0.0790
# Epoch 57/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9758 - loss: 0.0889
# Epoch 58/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9636 - loss: 0.1019
# Epoch 59/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0786
# Epoch 60/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9411 - loss: 0.1274
#
# Training model with 70 epochs:
# Epoch 1/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9411 - loss: 0.1307
# Epoch 2/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9428 - loss: 0.2688
# Epoch 3/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9532 - loss: 0.1446
# Epoch 4/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9098 - loss: 0.1829
# Epoch 5/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9549 - loss: 0.1114
# Epoch 6/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9532 - loss: 0.1213
# Epoch 7/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9653 - loss: 0.0874
# Epoch 8/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9775 - loss: 0.0931
# Epoch 9/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9324 - loss: 0.1326
# Epoch 10/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9758 - loss: 0.0765
# Epoch 11/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9775 - loss: 0.0874
# Epoch 12/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9653 - loss: 0.0899
# Epoch 13/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9549 - loss: 0.0871
# Epoch 14/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0776
# Epoch 15/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9758 - loss: 0.0724
# Epoch 16/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step - accuracy: 0.9653 - loss: 0.0836
# Epoch 17/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - accuracy: 0.9758 - loss: 0.0726
# Epoch 18/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.9879 - loss: 0.0633
# Epoch 19/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.9653 - loss: 0.0744
# Epoch 20/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9879 - loss: 0.0641
# Epoch 21/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9549 - loss: 0.0676
# Epoch 22/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.9775 - loss: 0.0741
# Epoch 23/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9758 - loss: 0.0538
# Epoch 24/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9532 - loss: 0.0613
# Epoch 25/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9879 - loss: 0.0544
# Epoch 26/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9653 - loss: 0.0826
# Epoch 27/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9653 - loss: 0.0565
# Epoch 28/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9879 - loss: 0.0567
# Epoch 29/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9775 - loss: 0.0587
# Epoch 30/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.9775 - loss: 0.0503
# Epoch 31/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9879 - loss: 0.0499
# Epoch 32/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9879 - loss: 0.0434
# Epoch 33/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0512
# Epoch 34/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9775 - loss: 0.0584
# Epoch 35/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.9775 - loss: 0.0528
# Epoch 36/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 1.0000 - loss: 0.0401
# Epoch 37/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9775 - loss: 0.0384
# Epoch 38/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9879 - loss: 0.0393
# Epoch 39/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.9775 - loss: 0.0492
# Epoch 40/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.9879 - loss: 0.0416
# Epoch 41/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 0.9879 - loss: 0.0413
# Epoch 42/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9549 - loss: 0.1046
# Epoch 43/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.9532 - loss: 0.0977
# Epoch 44/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.9879 - loss: 0.0590
# Epoch 45/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9532 - loss: 0.0708
# Epoch 46/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9879 - loss: 0.0576
# Epoch 47/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.9653 - loss: 0.0849
# Epoch 48/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9775 - loss: 0.0594
# Epoch 49/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9549 - loss: 0.0687
# Epoch 50/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9775 - loss: 0.0502
# Epoch 51/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9879 - loss: 0.0414
# Epoch 52/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0382
# Epoch 53/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.9879 - loss: 0.0318
# Epoch 54/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9653 - loss: 0.0550
# Epoch 55/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9775 - loss: 0.0509
# Epoch 56/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 1.0000 - loss: 0.0409
# Epoch 57/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9879 - loss: 0.0504
# Epoch 58/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9879 - loss: 0.0263
# Epoch 59/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 1.0000 - loss: 0.0316
# Epoch 60/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9775 - loss: 0.0390
# Epoch 61/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9879 - loss: 0.0333
# Epoch 62/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9775 - loss: 0.0406
# Epoch 63/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9775 - loss: 0.0321
# Epoch 64/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9879 - loss: 0.0297
# Epoch 65/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - accuracy: 0.9879 - loss: 0.0267
# Epoch 66/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 1.0000 - loss: 0.0346
# Epoch 67/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - accuracy: 0.9775 - loss: 0.0407
# Epoch 68/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9879 - loss: 0.0329
# Epoch 69/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9879 - loss: 0.0275
# Epoch 70/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0349
#
# Text Generated: Once upon a time there was a time there was a little girl named red riding hood she loved to visit her grandmother who lived in the woods one day her to take a basket of goodies to her grandmother on her way through the woods she met a big bad wolf who wanted to eat her way through the woods she met a big bad wolf who wanted to eat her way through
